# %%
arr = list(map(int, input("Enter array elements: ").split()))

last = arr[-1]

for i in range(len(arr) - 1, 0, -1):
    arr[i] = arr[i - 1]

arr[0] = last

print("Array after clockwise rotation:", arr)
# Out:
# Enter array elements: 1 2 3 4 5
# Array after clockwise rotation: [5, 1, 2, 3, 4]

# %%
arr = list(map(int, input("Enter array elements: ").split()))

current_sum = arr[0]
max_sum = arr[0]

for i in range(1, len(arr)):
    current_sum = max(arr[i], current_sum + arr[i])
    max_sum = max(max_sum, current_sum)

print("Maximum subarray sum:", max_sum)
# Out:
# Enter array elements: 2 3 -8 7 -1 2  3
# Maximum subarray sum: 11

# %%
nums = list(map(int, input("Enter sorted array elements: ").split()))
target = int(input("Enter target value: "))

left = 0
right = len(nums) - 1

while left <= right:
    mid = (left + right) // 2

    if nums[mid] == target:
        print("Index:", mid)
        break
    elif nums[mid] < target:
        left = mid + 1
    else:
        right = mid - 1
else:
    print("Insert position:", left)
# Out:
# Enter sorted array elements: 1 3 5 6
# Enter target value: 5
# Index: 2
